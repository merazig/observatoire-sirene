# %%
import main 
main
# Out:
# <module 'main' from 'C:\\Users\\PC\\Desktop\\observatoire _sirene\\observatoire-sirene\\main.py'>

# %%
# !python main.py 15
# Out:
# Connexion OK
# ======= Departement 15 =======
# siret_stock: 85194
# siret_fin: 197446
#             siret code_commune tranche_effectifs   libelle_commune code_ape
# 0  00721019800037        15175                NN      SAINT-CERNIN    60.2E
# 1  01484595200010        15014                NN          AURILLAC   81.10Z
# 2  01484613300016        15014                NN          AURILLAC   81.10Z
# 3  01484648900012        15014                01          AURILLAC   81.10Z
# 4  01484650500015        15012                01  ARPAJON-SUR-CERE   81.10Z
# 97825 lignes chargées
# Communes: 260
# temps: 43.638

# %%
# !python main.py 6
# Out:
# Connexion OK
# ======= Departement 06 =======
# siret_stock: 990660
# siret_fin: 2228889
# 1046658 lignes chargées
# Communes: 163
# temps: 154.11
